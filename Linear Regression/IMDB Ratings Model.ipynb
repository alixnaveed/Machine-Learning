# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('movie_metadata.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df['num_critic_for_reviews'].describe()
# Out:
# count    4993.000000
# mean      140.194272
# std       121.601675
# min         1.000000
# 25%        50.000000
# 50%       110.000000
# 75%       195.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
mean_crit = df['num_critic_for_reviews'].mean()
print(mean_crit)
df['num_critic_for_reviews'] = df['num_critic_for_reviews'].fillna(mean_crit)
df['num_critic_for_reviews'].describe()
# Out:
# 140.1942719807731
# count    5043.000000
# mean      140.194272
# std       120.997229
# min         1.000000
# 25%        50.000000
# 50%       111.000000
# 75%       194.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
mean_dur = df['duration'].mean()
print(mean_dur)
df['duration'] = df['duration'].fillna(mean_dur)
df['duration'].describe()
# Out:
# 107.2010739856802
# count    5043.000000
# mean      107.201074
# std        25.159932
# min         7.000000
# 25%        93.000000
# 50%       103.000000
# 75%       118.000000
# max       511.000000
# Name: duration, dtype: float64

# %%
mean_dir = df['director_facebook_likes'].mean()
print(mean_dir)
df['director_facebook_likes'] = df['director_facebook_likes'].fillna(mean_dir)
df['director_facebook_likes'].describe()
# Out:
# 686.5092123911724
# count     5043.000000
# mean       686.509212
# std       2784.162531
# min          0.000000
# 25%          7.000000
# 50%         52.000000
# 75%        218.000000
# max      23000.000000
# Name: director_facebook_likes, dtype: float64

# %%
mean_act3 = df['actor_3_facebook_likes'].mean()
print(mean_act3)
df['actor_3_facebook_likes'] = df['actor_3_facebook_likes'].fillna(mean_act3)
df['actor_3_facebook_likes'].describe()
# Out:
# 645.0097609561753
# count     5043.000000
# mean       645.009761
# std       1661.239692
# min          0.000000
# 25%        134.500000
# 50%        374.000000
# 75%        638.000000
# max      23000.000000
# Name: actor_3_facebook_likes, dtype: float64

# %%
mean_act1 = df['actor_1_facebook_likes'].mean()
print(mean_act1)
df['actor_1_facebook_likes'] = df['actor_1_facebook_likes'].fillna(mean_act1)
df['actor_1_facebook_likes'].describe()
# Out:
# 6560.04706115965
# count      5043.000000
# mean       6560.047061
# std       15010.328553
# min           0.000000
# 25%         615.500000
# 50%         989.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
mean_gr = df['gross'].mean()
print(mean_gr)
df['gross'] = df['gross'].fillna(mean_gr)
df['gross'].describe()
# Out:
# 48468407.52680933
# count    5.043000e+03
# mean     4.846841e+07
# std      6.216318e+07
# min      1.620000e+02
# 25%      8.460992e+06
# 50%      3.743230e+07
# 75%      5.135707e+07
# max      7.605058e+08
# Name: gross, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     5043 non-null   float64
#  3   duration                   5043 non-null   float64
#  4   director_facebook_likes    5043 non-null   float64
#  5   actor_3_facebook_likes     5043 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5043 non-null   float64
#  8   gross                      5043 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.head(500)
# Out:
#                 color  num_critic_for_reviews    duration  \
# 0               Color              723.000000  178.000000
# 1               Color              302.000000  169.000000
# 2               Color              602.000000  148.000000
# 3               Color              813.000000  164.000000
# 4                 NaN              140.194272  107.201074
# ..                ...                     ...         ...
# 495             Color              174.000000  119.000000
# 496             Color              101.000000   91.000000
# 497   Black and White              205.000000  118.000000
# 498             Color              123.000000  116.000000
# 499             Color               79.000000  177.000000
#
#      director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 0                        0.0              855.000000      Joel David Moore
# 1                      563.0             1000.000000         Orlando Bloom
# ...

# %%
df = df.drop(['director_name'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-6e64358663e3> in <module>
# ----> 1 df = df.drop(['director_name'], axis=1)
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df['color'].describe()
# Out:
# count      5024
# unique        2
# top       Color
# freq       4815
# Name: color, dtype: object

# %%
df['color'] = df['color'].fillna("Color")
df['color'] = df['color'].replace({' Black and White':0, 'Color':1})
df['color'].describe()
# Out:
# count    5043.000000
# mean        0.958556
# std         0.199334
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: color, dtype: float64

# %%
df.head(1000)
# Out:
#      color  num_critic_for_reviews    duration  director_facebook_likes  \
# 0        1              723.000000  178.000000                      0.0
# 1        1              302.000000  169.000000                    563.0
# 2        1              602.000000  148.000000                      0.0
# 3        1              813.000000  164.000000                  22000.0
# 4        1              140.194272  107.201074                    131.0
# ..     ...                     ...         ...                      ...
# 995      1               51.000000  117.000000                     31.0
# 996      1               98.000000   87.000000                      9.0
# 997      1              315.000000  129.000000                  16000.0
# 998      1              136.000000  115.000000                     58.0
# 999      0               61.000000  132.000000                    503.0
#
#      actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# ...

# %%
df = df.drop(['genres', 'actor_1_name', 'movie_title','actor_3_name','movie_imdb_link','country'], axis=1)

# %%
df.head()
# Out:
#   color  num_critic_for_reviews    duration  director_facebook_likes  \
# 0     1              723.000000  178.000000                      0.0
# 1     1              302.000000  169.000000                    563.0
# 2     1              602.000000  148.000000                      0.0
# 3     1              813.000000  164.000000                  22000.0
# 4     1              140.194272  107.201074                    131.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0              855.000000  Joel David Moore                  1000.0
# 1             1000.000000     Orlando Bloom                 40000.0
# 2              161.000000      Rory Kinnear                 11000.0
# 3            23000.000000    Christian Bale                 27000.0
# 4              645.009761        Rob Walker                   131.0
#
#           gross  num_voted_users  cast_total_facebook_likes  ...  \
# 0  7.605058e+08           886204                       4834  ...
# ...

# %%
df = df.drop(['actor_2_name'], axis=1)

# %%
df.head()
# Out:
#   color  num_critic_for_reviews    duration  director_facebook_likes  \
# 0     1              723.000000  178.000000                      0.0
# 1     1              302.000000  169.000000                    563.0
# 2     1              602.000000  148.000000                      0.0
# 3     1              813.000000  164.000000                  22000.0
# 4     1              140.194272  107.201074                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# 0              855.000000                  1000.0  7.605058e+08
# 1             1000.000000                 40000.0  3.094042e+08
# 2              161.000000                 11000.0  2.000742e+08
# 3            23000.000000                 27000.0  4.481306e+08
# 4              645.009761                   131.0  4.846841e+07
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# ...

# %%
df = df.drop(['plot_keywords'], axis=1)

# %%
df.head()
# Out:
#   color  num_critic_for_reviews    duration  director_facebook_likes  \
# 0     1              723.000000  178.000000                      0.0
# 1     1              302.000000  169.000000                    563.0
# 2     1              602.000000  148.000000                      0.0
# 3     1              813.000000  164.000000                  22000.0
# 4     1              140.194272  107.201074                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# 0              855.000000                  1000.0  7.605058e+08
# 1             1000.000000                 40000.0  3.094042e+08
# 2              161.000000                 11000.0  2.000742e+08
# 3            23000.000000                 27000.0  4.481306e+08
# 4              645.009761                   131.0  4.846841e+07
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# ...

# %%
df = df.drop(['language','content_rating'], axis=1)

# %%
df.head()
# Out:
#   color  num_critic_for_reviews    duration  director_facebook_likes  \
# 0     1              723.000000  178.000000                      0.0
# 1     1              302.000000  169.000000                    563.0
# 2     1              602.000000  148.000000                      0.0
# 3     1              813.000000  164.000000                  22000.0
# 4     1              140.194272  107.201074                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# 0              855.000000                  1000.0  7.605058e+08
# 1             1000.000000                 40000.0  3.094042e+08
# 2              161.000000                 11000.0  2.000742e+08
# 3            23000.000000                 27000.0  4.481306e+08
# 4              645.009761                   131.0  4.846841e+07
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# ...

# %%
df['facenumber_in_poster'] = df['facenumber_in_poster'].fillna(2)

# %%
df['facenumber_in_poster'].describe()
# Out:
# count    5043.000000
# mean        1.372794
# std         2.011231
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max        43.000000
# Name: facenumber_in_poster, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5043 non-null   object
#  1   num_critic_for_reviews     5043 non-null   float64
#  2   duration                   5043 non-null   float64
#  3   director_facebook_likes    5043 non-null   float64
#  4   actor_3_facebook_likes     5043 non-null   float64
#  5   actor_1_facebook_likes     5043 non-null   float64
#  6   gross                      5043 non-null   float64
#  7   num_voted_users            5043 non-null   int64
#  8   cast_total_facebook_likes  5043 non-null   int64
#  9   facenumber_in_poster       5043 non-null   float64
#  10  num_user_for_reviews       5043 non-null   float64
#  11  budget                     5043 non-null   float64
#  12  title_year                 4935 non-null   float64
# ...

# %%
mean_nufr = df['num_user_for_reviews'].mean()
print(mean_nufr)
df['num_user_for_reviews'] = df['num_user_for_reviews'].fillna(mean_nufr)
df['num_user_for_reviews'].describe()
# Out:
# 272.77080844285143
# count    5043.000000
# mean      272.770808
# std       377.194912
# min         1.000000
# 25%        65.000000
# 50%       157.000000
# 75%       324.000000
# max      5060.000000
# Name: num_user_for_reviews, dtype: float64

# %%
mean_bud = df['budget'].mean()
print(mean_bud)
df['budget'] = df['budget'].fillna(mean_bud)
df['budget'].describe()
# Out:
# 39752620.436387606
# count    5.043000e+03
# mean     3.975262e+07
# std      1.958004e+08
# min      2.180000e+02
# 25%      7.000000e+06
# 50%      2.300000e+07
# 75%      4.000000e+07
# max      1.221550e+10
# Name: budget, dtype: float64

# %%
df = df.drop(['title_year'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5043 non-null   object
#  1   num_critic_for_reviews     5043 non-null   float64
#  2   duration                   5043 non-null   float64
#  3   director_facebook_likes    5043 non-null   float64
#  4   actor_3_facebook_likes     5043 non-null   float64
#  5   actor_1_facebook_likes     5043 non-null   float64
#  6   gross                      5043 non-null   float64
#  7   num_voted_users            5043 non-null   int64
#  8   cast_total_facebook_likes  5043 non-null   int64
#  9   facenumber_in_poster       5043 non-null   float64
#  10  num_user_for_reviews       5043 non-null   float64
#  11  budget                     5043 non-null   float64
#  12  actor_2_facebook_likes     5043 non-null   float64
# ...

# %%
mean_act2 = df['actor_2_facebook_likes'].mean()
print(mean_act2)
df['actor_2_facebook_likes'] = df['actor_2_facebook_likes'].fillna(mean_act2)
df['actor_2_facebook_likes'].describe()
# Out:
# 1651.7544731610337
# count      5043.000000
# mean       1651.754473
# std        4037.224104
# min           0.000000
# 25%         281.000000
# 50%         596.000000
# 75%         919.000000
# max      137000.000000
# Name: actor_2_facebook_likes, dtype: float64

# %%
df['aspect_ratio'] = df['aspect_ratio'].fillna(2.35)
df['aspect_ratio'].describe()
# Out:
# count    5043.000000
# mean        2.228858
# std         1.339542
# min         1.180000
# 25%         1.850000
# 50%         2.350000
# 75%         2.350000
# max        16.000000
# Name: aspect_ratio, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5043 non-null   int64
#  1   num_critic_for_reviews     5043 non-null   float64
#  2   duration                   5043 non-null   float64
#  3   director_facebook_likes    5043 non-null   float64
#  4   actor_3_facebook_likes     5043 non-null   float64
#  5   actor_1_facebook_likes     5043 non-null   float64
#  6   gross                      5043 non-null   float64
#  7   num_voted_users            5043 non-null   int64
#  8   cast_total_facebook_likes  5043 non-null   int64
#  9   facenumber_in_poster       5043 non-null   float64
#  10  num_user_for_reviews       5043 non-null   float64
#  11  budget                     5043 non-null   float64
#  12  actor_2_facebook_likes     5043 non-null   float64
# ...

# %%
Y=df['imdb_score']
x=df.drop(['imdb_score'], axis=1)

# %%
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.3,random_state=101)

# %%
X_train
# Out:
#       color  num_critic_for_reviews  duration  director_facebook_likes  \
# 4897      1              122.000000      99.0                      0.0
# 3811      1              140.194272      87.0                     49.0
# 3265      1               66.000000      98.0                     17.0
# 4048      1              188.000000     108.0                     43.0
# 2681      1               45.000000     114.0                     73.0
# ...     ...                     ...       ...                      ...
# 4171      1               29.000000     140.0                    133.0
# 599       1              358.000000     119.0                    845.0
# 1361      1               38.000000     118.0                     11.0
# 1547      1              131.000000     103.0                      9.0
# 4959      1               21.000000      81.0                    467.0
#
#       actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# ...

# %%
Y_train
# Out:
# 4897    8.0
# 3811    5.5
# 3265    4.5
# 4048    5.7
# 2681    6.0
#        ...
# 4171    7.8
# 599     6.5
# 1361    6.4
# 1547    6.2
# 4959    7.0
# Name: imdb_score, Length: 3530, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lirm = LinearRegression()
lirm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lirm.predict([[1,100,120,50,75,125,51325467,1000,1999,3,690,3269420,500,2.35,5000]])
# Out:
# array([5.88949658])
